# %%
import numpy as np
import pandas as pd

#defining the daata set location
dataset =r'C:\Users\Professor Moruf\Desktop\pandas\telecom_churn.csv'

#convert to 2deecimal
pd.set_option("display.precision",2)

#Read the CSV file
df = pd.read_csv(dataset)

df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df['Churn']=df['Churn'].astype('int64')

# %%
df['Churn']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
#Work on non numrical by specifying in the method

df.describe(include=['object','bool'])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    2850
# 1     483
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# 0    0.86
# 1    0.14
# Name: proportion, dtype: float64

# %%
df.sort_values(by='Total day minutes', ascending= True)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
# ...    ...             ...        ...                ...             ...
# 605     MO             112        415                 No              No
# 156     OH              83        415                 No              No
# 2594    OH             115        510                Yes              No
# 985     NY              64        415                Yes              No
# 365     CO             154        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#sorting certain columns
df.sort_values(by=['Churn','Total day charge'], ascending=[True,False]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 688     MN              13        510                 No             Yes
# 2259    NC             210        415                 No             Yes
# 534     LA              67        510                 No              No
# 575     SD             114        415                 No             Yes
# 2858    AL             141        510                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 688                      21              315.6              105
# 2259                     31              313.8               87
# 534                       0              310.4               97
# 575                      36              309.9               90
# 2858                     28              308.0              123
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
#looking at those who left and their respective rows
df[df['Churn']==1]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#looking at those who left and their respective rows
df[df['Churn'] == 1].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
# ...

# %%
df['Churn'].mean()
# Out:
# 0.14491449144914492

# %%
#looking at those who left and their respective rows
df[df['Churn'] == 0].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
# ...

# %%
#looking at those who left and their respective rows
mn=df[df['Churn'] == 0]
call=mn.mean
call
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
# ...

# %%
#amunt oftime user who left spend on phone
df[df['Churn']==1]['Total day minutes'].mean()
# Out:
# 206.91407867494823

# %%
df[(df['Churn']==0) & (df['International plan']== 'No')]['Total intl minutes'].max()
# Out:
# 18.9

# %%
#slicing
df.loc[0:5,'State':'Area code']
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
df.iloc[0:5,0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %%
df[1:]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#using the apply method to apply functions
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %%
#choosing state that start with  w 
df[df['State'].apply(lambda State: State[0]== 'W')].head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 9     WV             141        415                Yes             Yes
# 26    WY              57        408                 No             Yes
# 44    WI              64        510                 No              No
# 49    WY              97        415                 No             Yes
# 54    WY              87        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 9                      37              258.6               84
# 26                     39              213.0              115
# 44                      0              154.0               67
# 49                     24              133.2              135
# 54                      0              151.0               83
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 9              43.96              222.0              111             18.87
# ...

# %%
#changing a particular column just Vlookup in excel

d={'No':False, 'Yes':True}
df['International plan']=df['International plan'].map(d)
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                NaN             Yes
# 1    OH             107        415                NaN             Yes
# 2    NJ             137        415                NaN              No
# 3    OH              84        408                NaN              No
# 4    OK              75        415                NaN              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#changing a particular column just Vlookup in excel(2nd method)
df.replace({'Voice mail plan':d})
# Out:
#      State  Account length  Area code International plan  Voice mail plan  \
# 0       KS             128        415              False             True
# 1       OH             107        415              False             True
# 2       NJ             137        415              False            False
# 3       OH              84        408               True            False
# 4       OK              75        415               True            False
# ...    ...             ...        ...                ...              ...
# 3328    AZ             192        415                NaN             True
# 3329    WV              68        415                NaN            False
# 3330    RI              28        510                NaN            False
# 3331    CT             184        510                NaN            False
# 3332    TN              74        415                NaN             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#Working with groupby method function 
column_show=['Total day minutes','Total eve minutes', 'Total night minutes']
df.groupby(['Churn'])[column_show].describe()
# Out:
#       Total day minutes                                                    \
#                   count    mean    std  min     25%    50%     75%    max
# Churn
# 0                2850.0  175.18  50.18  0.0  142.83  177.2  210.30  315.6
# 1                 483.0  206.91  69.00  0.0  153.25  217.6  265.95  350.8
#
#       Total eve minutes          ...                Total night minutes  \
#                   count    mean  ...     75%    max               count
# Churn                            ...
# 0                2850.0  199.04  ...  233.20  361.8              2850.0
# 1                 483.0  212.41  ...  249.45  363.7               483.0
#
#
#          mean    std   min     25%     50%     75%    max
# Churn
# 0      200.13  51.11  23.2  165.90  200.25  234.90  395.0
# 1      205.23  47.13  47.4  171.25  204.80  239.85  354.9
#
# [2 rows x 24 columns]

# %%
#Working with groupby method function 
column_show=['Total day minutes','Total eve minutes', 'Total night minutes']
df.groupby(['Churn'])[column_show].describe(percentiles=[])
# Out:
#       Total day minutes                                   Total eve minutes  \
#                   count    mean    std  min    50%    max             count
# Churn
# 0                2850.0  175.18  50.18  0.0  177.2  315.6            2850.0
# 1                 483.0  206.91  69.00  0.0  217.6  350.8             483.0
#
#                                          Total night minutes                 \
#          mean    std   min    50%    max               count    mean    std
# Churn
# 0      199.04  50.29   0.0  199.6  361.8              2850.0  200.13  51.11
# 1      212.41  51.73  70.9  211.3  363.7               483.0  205.23  47.13
#
#
#         min     50%    max
# Churn
# 0      23.2  200.25  395.0
# 1      47.4  204.80  354.9

# %%
#Working with groupby method function 
column_show=['Total day minutes','Total eve minutes', 'Total night minutes']
df.groupby(['Churn'])[column_show].agg([np.mean,np.median,np.max,np.min])
# Out:
#       Total day minutes                    Total eve minutes                \
#                    mean median   amax amin              mean median   amax
# Churn
# 0                175.18  177.2  315.6  0.0            199.04  199.6  361.8
# 1                206.91  217.6  350.8  0.0            212.41  211.3  363.7
#
#             Total night minutes
#        amin                mean  median   amax  amin
# Churn
# 0       0.0              200.13  200.25  395.0  23.2
# 1      70.9              205.23  204.80  354.9  47.4

# %%
#getting contigency table with two columns
pd.crosstab(df['Churn'],df['International plan'] , normalize=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.pivot_table(['Total day minutes','Total eve minutes', 'Total night minutes'],['Area code'],aggfunc='mean')
# Out:
#            Total day minutes  Total eve minutes  Total night minutes
# Area code
# 408                   177.18             201.28               199.21
# 415                   181.59             200.65               202.04
# 510                   178.79             201.32               200.23

# %% [markdown]
# ##NEW DATA SET

# %%
wine=r'C:\Users\Professor Moruf\Downloads\winemag-data_first150k.csv'

# %%
df=pd.read_csv(wine)
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df.shape
# Out:
# (150930, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
getprovince=df['province']
getprovince.value_counts().head(10)
# Out:
# province
# California          44508
# Washington           9750
# Tuscany              7281
# Bordeaux             6111
# Northern Spain       4892
# Mendoza Province     4742
# Oregon               4589
# Burgundy             4308
# Piedmont             4093
# Veneto               3962
# Name: count, dtype: int64

# %%
getprovince.value_counts().head().plot.bar()
# Out:
# <Axes: xlabel='province'>

# %%
#Get percentage
(df['province'].value_counts().head(10)/len(df)).plot.bar()
# Out:
# <Axes: xlabel='province'>

# %%
#Line graph is not good for nominal categorical data

df['points']
# Out:
# 0         96
# 1         96
# 2         96
# 3         96
# 4         95
#           ..
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 150930, dtype: int64

# %%
getpoint =df['points'].value_counts().sort_index().plot.line()

# %%
getpoint =df['points'].value_counts().sort_index().plot.area()

# %%
price=df['price']

# %%
df[price < 200]
# Out:
#         Unnamed: 0 country                                        description  \
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# 5                5   Spain  Deep, dense and pure from the opening bell, th...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df[price<200]['price'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[price < 200]['price'].plot.bar()
